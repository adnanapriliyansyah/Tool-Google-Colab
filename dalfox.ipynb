# %%
! apt update
! apt upgrade

# %%
# !sudo apt-get install golang-go

# %%
# !go install github.com/hahwul/dalfox/v2@latest

# %%
# !cp /root/go/bin/dalfox /usr/local/bin

# %%
# !dalfox file /content/target.txt -b hawhul.xss.ht -o /content/hasil.txt
